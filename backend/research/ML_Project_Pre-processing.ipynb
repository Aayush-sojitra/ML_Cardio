# %% [markdown]
# #                   <center><b> Aayush Sojitra [23010101253]</b></center>

# %% [markdown]
# # <i>Cardiovascular Disease</i>

# %% [markdown]
# # <b>---------------------------------------------------------------------</b>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# ### Load Dataset

# %%
data = pd.read_csv("../data/cardio_train.csv", sep=";")

# %% [markdown]
# ### Print Data

# %%
data
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %% [markdown]
# ### Columns

# %%
data.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %% [markdown]
# ### Info of Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %% [markdown]
# ### Data Describe

# %%
data.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
data["cardio"].value_counts()
# Out:
# cardio
# 0    35021
# 1    34979
# Name: count, dtype: int64

# %% [markdown]
# ### Gender Label Mapping

# %%
# data["gender"]= data["gender"].replace({2:"Male", 1:"Female"})
# data.head(5)

# %% [markdown]
# ### No. of Rows and Columns

# %%
data.shape
# Out:
# (70000, 13)

# %% [markdown]
# ### Count of Null values

# %%
data.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %% [markdown]
# ### Age

# %%
data["age"]= (data["age"]/365.25 ).astype(int)

data.head(10)
# Out:
#    id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0    0       2     168    62.0    110     80            1     1      0
# 1   1    0       1     156    85.0    140     90            3     1      0
# 2   2    0       1     165    64.0    130     70            3     1      0
# 3   3    0       2     169    82.0    150    100            1     1      0
# 4   4    0       1     156    56.0    100     60            1     1      0
# 5   8    0       1     151    67.0    120     80            2     2      0
# 6   9    0       1     157    93.0    130     80            3     1      0
# 7  12    0       2     178    95.0    130     90            3     3      0
# 8  13    0       1     158    71.0    110     70            1     1      0
# 9  14    0       1     164    68.0    110     60            1     1      0
#
#    alco  active  cardio        BMI
# 0     0       1       0  21.967120
# 1     0       1       1  34.927679
# 2     0       0       1  23.507805
# ...

# %% [markdown]
# ### Cholesterol Label Mapping

# %%
# data["cholesterol"]= data["cholesterol"].replace({1:"normal",2:"above normal", 3:"well above normal"})

# %% [markdown]
# ### Glucose Lable Mapping

# %%
# data["gluc"]= data["gluc"].replace({1:"normal",2:"above normal", 3:"well above normal"})
# data.head(5)

# %% [markdown]
# ### Only Cardio column

# %%
data['cardio']
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %% [markdown]
# ### last 10 row

# %%
data.tail(10)
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 69990  99986   41       1     168    72.0    110     70            1     1
# 69991  99988   56       1     159    72.0    130     90            2     2
# 69992  99990   51       1     161    56.0    170     90            1     1
# 69993  99991   54       1     172    70.0    130     90            1     1
# 69994  99992   58       1     165    80.0    150     80            1     1
# 69995  99993   53       2     168    76.0    120     80            1     1
# 69996  99995   62       1     158   126.0    140     90            2     2
# 69997  99996   52       2     183   105.0    180     90            3     1
# 69998  99998   61       1     163    72.0    135     80            1     2
# 69999  99999   56       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 69990      0     0       1       1
# 69991      0     0       1       0
# 69992      0     0       1       1
# ...

# %% [markdown]
# ### 3rd row

# %%
data.iloc[3]
# Out:
# id               3.0
# age             48.0
# gender           2.0
# height         169.0
# weight          82.0
# ap_hi          150.0
# ap_lo          100.0
# cholesterol      1.0
# gluc             1.0
# smoke            0.0
# alco             0.0
# active           1.0
# cardio           1.0
# Name: 3, dtype: float64

# %% [markdown]
# ### No. of rows where cardio & smoke = 1

# %%
data[(data['cardio'] == 1) & (data['smoke'] == 1)].shape[0]
# Out:
# 2929

# %% [markdown]
# ### BMI Calculation

# %%
data['BMI'] = data['weight'] / ((data['height']/100)**2)
data[['height','weight','BMI']]
# Out:
#        height  weight        BMI
# 0         168    62.0  21.967120
# 1         156    85.0  34.927679
# 2         165    64.0  23.507805
# 3         169    82.0  28.710479
# 4         156    56.0  23.011177
# ...       ...     ...        ...
# 69995     168    76.0  26.927438
# 69996     158   126.0  50.472681
# 69997     183   105.0  31.353579
# 69998     163    72.0  27.099251
# 69999     170    72.0  24.913495
#
# [70000 rows x 3 columns]

# %% [markdown]
# ### Data where age>50

# %%
data[data['age']>50]
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 1          1   55       1     156    85.0    140     90            3     1
# 2          2   52       1     165    64.0    130     70            3     1
# 5          8   60       1     151    67.0    120     80            2     2
# 6          9   61       1     157    93.0    130     80            3     1
# 7         12   62       2     178    95.0    130     90            3     3
# ...      ...  ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993   53       2     168    76.0    120     80            1     1
# 69996  99995   62       1     158   126.0    140     90            2     2
# 69997  99996   52       2     183   105.0    180     90            3     1
# 69998  99998   61       1     163    72.0    135     80            1     2
# 69999  99999   56       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio        BMI
# ...

# %% [markdown]
# ## Charts

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Age Distribution

# %%
# sb.histplot(data["age"], bins=30, kde=True)
# plt.title("Age Distribution")
# plt.show()

# %% [markdown]
# ### Barchart of Cardio groupby Gender

# %%
# data.groupby('gender')['cardio'].mean().plot(kind='bar')
# plt.title("Heart Disease Rate by Gender")
# plt.xlabel("Gender")
# plt.ylabel("Heart Disease Rate")
# plt.show()

# %% [markdown]
# ### barchart of Cardio

# %%
# data['cardio'].value_counts().plot(kind='bar')

# %% [markdown]
# ### histogram

# %%
# plt.hist(data['age'], bins=20)
# plt.title("Age Distribution")
# plt.xlabel("Age (Years)")
# plt.ylabel("Number of Patients")
# plt.show()

# %% [markdown]
# ### Weight vs Cardiovascular Disease

# %%
# sb.boxplot(x="cardio", y="weight", data=data)
# plt.title("Weight vs Cardiovascular Disease")
# plt.show()

# %% [markdown]
# ### Height vs Weight Scatter Plot

# %%
# sb.scatterplot(x="height", y="weight", hue="cardio", data=data)
# plt.title("Height vs Weight")
# plt.show()

# %% [markdown]
# ### Bar plot

# %%
# sb.barplot(x="cholesterol", y="cardio", data=data)
# plt.title("Cholesterol Level vs Cardio")
# plt.show()

# %%
# sb.pairplot(
#     data[["age","height","weight","ap_hi","ap_lo","cardio"]],
#     hue="cardio"
# )
# plt.show()

# %% [markdown]
# ### correlation_matrix

# %%
# correlation_matrix = data.corr(numeric_only=True)
# correlation_matrix

# %% [markdown]
# ### Heatmap

# %%
# correlation_matrix = data.corr(numeric_only=True)
# plt.figure(figsize=(8, 4))
# sb.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f") 
# plt.title("Visualization of correlation matrix")
# plt.show()

# %%
data.head()
# Out:
#    id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0   50       2     168    62.0    110     80            1     1      0
# 1   1   55       1     156    85.0    140     90            3     1      0
# 2   2   52       1     165    64.0    130     70            3     1      0
# 3   3   48       2     169    82.0    150    100            1     1      0
# 4   4   48       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio        BMI
# 0     0       1       0  21.967120
# 1     0       1       1  34.927679
# 2     0       0       1  23.507805
# 3     0       1       1  28.710479
# 4     0       0       0  23.011177

# %% [markdown]
# ### Basic Pre-processing

# %%
# Dropping ID column, removing duplicate rows, and creating age_years column from age(in days)

df_clean = data.copy()

df_clean.drop(columns=['id'], inplace=True)
df_clean.drop_duplicates(inplace=True)

df_clean['age'] = (df_clean['age'] / 365.25).astype(int)

# %% [markdown]
# ### Invalid blood pressure values detected:

# %%
# Cleaning dataset by removing invalid BP values, unrealistic BMI values,
# and keeping only medically valid categorical values

# Blood Pressure sanity filters
df_clean = df_clean[(df_clean['ap_hi'] >= 80) & (df_clean['ap_hi'] <= 250)]
df_clean = df_clean[(df_clean['ap_lo'] >= 40) & (df_clean['ap_lo'] <= 200)]
df_clean = df_clean[df_clean['ap_hi'] > df_clean['ap_lo']]

# BMI
df_clean['bmi'] = df_clean['weight'] / ((df_clean['height']/100)**2)
df_clean = df_clean[(df_clean['bmi'] > 10) & (df_clean['bmi'] < 60)]

# Valid category values
df_clean = df_clean[df_clean['cholesterol'].isin([1,2,3])]
df_clean = df_clean[df_clean['gluc'].isin([1,2,3])]
df_clean = df_clean[df_clean['smoke'].isin([0,1])]
df_clean = df_clean[df_clean['alco'].isin([0,1])]
df_clean = df_clean[df_clean['active'].isin([0,1])]
df_clean = df_clean[df_clean['gender'].isin([1,2])]

# %%
df_clean
# Out:
#        height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  gender  \
# 0         168    62.0    110     80            1     1      0     0       2
# 1         156    85.0    140     90            3     1      0     0       1
# 2         165    64.0    130     70            3     1      0     0       1
# 3         169    82.0    150    100            1     1      0     0       2
# 4         156    56.0    100     60            1     1      0     0       1
# ...       ...     ...    ...    ...          ...   ...    ...   ...     ...
# 69995     168    76.0    120     80            1     1      1     0       2
# 69996     158   126.0    140     90            2     2      0     0       1
# 69997     183   105.0    180     90            3     1      0     1       2
# 69998     163    72.0    135     80            1     2      0     0       1
# 69999     170    72.0    120     80            2     1      0     0       1
#
#        active  age  cardio        bmi
# ...

# %% [markdown]
# ### Save CSV

# %%
df_clean.to_csv("../data/clean_cardio_data.csv", index=False)
